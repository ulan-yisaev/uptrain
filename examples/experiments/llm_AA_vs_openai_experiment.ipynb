# %% [markdown]
# <h1 align="center">
#   <a href="https://www.nlga.niedersachsen.de/startseite">
#     <img width="300" src="https://www.nlga.niedersachsen.de/assets/image/246974" alt="NLGA">
#   </a>
# </h1>

# %% [markdown]
# ## Experimenting with different LLMs - Aleph Alpha Luminous-supreme-control vs GPT-35-turbo

# %%
# define configuration for dynamic experiment handling
EXPERIMENT_NAME = "GPT_35_vs_Luminous_Supreme"

# %% [markdown]
# **Overview**: In this notebook, we will compare different LLM providers. We will be using around 35 example questions from the [Testfragen](https://secure-confluence.nortal.com/display/NLGAC/Testfragen) dataset and evaluate the response on different criteria to determine which of the two models performs better.
#
# We have used the following metrics from UpTrain's library:
#
# 1. [Response Conciseness](https://docs.uptrain.ai/predefined-evaluations/response-quality/response-conciseness): Evaluates how concise the generated response is or if it has any additional irrelevant information for the question asked.
#
# 2. [Response Matching](https://docs.uptrain.ai/predefined-evaluations/ground-truth-comparison/response-matching): Evaluates how well the response generated by the LLM aligns with the provided ground truth.
#
# 3. [Factual Accuracy](https://docs.uptrain.ai/predefined-evaluations/context-awareness/factual-accuracy): Evaluates whether the response generated is factually correct and grounded by the provided context.
#
# 4. [Context Utilization](https://docs.uptrain.ai/predefined-evaluations/context-awareness/context-utilization): Evaluates how complete the generated response is for the question specified given the information provided in the context. Also known as Reponse Completeness wrt context (RESPONSE_COMPLETENESS_WRT_CONTEXT)
#
# 5. [Response Relevance](https://docs.uptrain.ai/predefined-evaluations/response-quality/response-relevance): Evaluates how relevant the generated response was to the question specified.
# 6. **What is Response Validity?**: In some cases, an LLM might fail to generate a response due to reasons like limited knowledge or the asked question not being clear. Response Validity score can be used to identify these cases, where a model is not generating an informative response.
# For example, if the question asked is "What is the chemical formula of chlorophyll?", a valid response would be "The  formula for chlorophyll is C55H72O5N4Mg." An invalid response could be "Sorry, I have no idea about that."
# 7. **What is Guideline Adherence?**: [Guideline adherence](https://github.com/uptrain-ai/uptrain/blob/main/examples/checks/custom/guideline_adherence.ipynb) refers to the extent to which the LLM follows a given guideline, rule, or protocol. Given the complexity of LLMs, it is crucial to define certain guidelines, be it in terms of the structure of the output or the constraints on the content of the output or protocols on the decision-making capabilities of the LLM (agents).
# For example, for an LLM-powered chatbot agent trained to perform appointment booking tasks only, you want to make sure that the LLM is following the guideline: "The agent should redirect all the queries to the human agent, except the ones related to appointment booking."
#
# Each score has a value between 0 and 1.
#
# Complete list of UpTrain's supported metrics [here](https://docs.uptrain.ai/predefined-evaluations/overview)

# %% [markdown]
# ### Install Dependencies

# %%
# %pip install openai uptrain together lazy_loader fsspec pandas polars networkx pydantic_settings aiolimiter

# %%
import os
from dotenv import load_dotenv
import polars as pl 
import shutil
from datetime import datetime
import time
from openai import OpenAI

# %% [markdown]
# ### Authentication and Configuration
#
# Let's define the required api keys - mainly the Azure openai key (for generating responses).
# Please also ensure that the dataset path is correctly defined in the configuration.
# Do not forget to set the API_KEY and BASE_URL for the LLM API Endpoint provider.

# %%
# Load the environment variables from the .env file
load_dotenv()

CONFIG = {
    # The model name used to generate responses
    "GENERATE_MODEL_NAME": "gpt-35-turbo-16k-deployment",
    "AA_MODEL_NAME": "luminous-supreme-control",
    # Guideline name used in the Guideline Adherence check 
    "GUIDELINE_NAME": "Strict_Context",
    # dataset path
    # "DATASET_PATH": "nlga_dataset_AA_small.jsonl",
    "DATASET_PATH": "./nlga_dataset_AA.jsonl",
    "RESULTS_DIR": "./results/",
    "AZURE_OPENAI_API_KEY": os.getenv("AZURE_OPENAI_API_KEY"),
    "AZURE_API_VERSION": os.getenv("AZURE_API_VERSION"),
    "AZURE_API_BASE": os.getenv("AZURE_API_BASE"),
    # Azure deployments:
    "GPT_35_TURBO_16K": "gpt-35-turbo-16k-deployment",
    "GPT_4": "gpt4"
}

# Azure deployment used to evaluate 
EVAL_MODEL_NAME = "azure/gpt4"
# EVAL_MODEL_NAME = "azure/gpt35-16k"

def get_experiment_file_path(extension):
    filename = f"{EXPERIMENT_NAME.replace(' ', '_').replace('-', '_').lower()}_experiment.{extension}"
    return os.path.join(CONFIG['RESULTS_DIR'], filename)

jsonl_file_path = get_experiment_file_path('jsonl')
csv_file_path = get_experiment_file_path('csv')

# %%
# Utility functions for API and file operations
from openai import AzureOpenAI

def initialize_azure_openai_client():
    # gets the API Key from environment variable AZURE_OPENAI_API_KEY
    return AzureOpenAI(api_version=CONFIG["AZURE_API_VERSION"], 
                       azure_endpoint=CONFIG["AZURE_API_BASE"])

def ensure_directory_exists(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_dataset(path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"The specified dataset path does not exist: {path}")
    return pl.read_ndjson(path)
# dataset = pl.read_ndjson(dataset_path).select(pl.col(["question", "ground_truth", "context"]))

# %% [markdown]
# ### Load the testing dataset

# %%
ensure_directory_exists(CONFIG['RESULTS_DIR'])
dataset = read_dataset(CONFIG['DATASET_PATH'])
filtered_dataset = dataset.filter(dataset["idx"] > 100)
filtered_dataset
# Out:
# shape: (4, 5)
# ┌─────┬──────────────────────────────┬─────────────────────────────┬─────────────────────────────┬─────────────────────────────┐
# │ idx ┆ question                     ┆ response                    ┆ ground_truth                ┆ context                     │
# │ --- ┆ ---                          ┆ ---                         ┆ ---                         ┆ ---                         │
# │ i64 ┆ str                          ┆ str                         ┆ str                         ┆ str                         │
# ╞═════╪══════════════════════════════╪═════════════════════════════╪═════════════════════════════╪═════════════════════════════╡
# │ 104 ┆ Welche Erreger werden in     ┆ Armin erfasst keine         ┆ * Gramnegative Bakterien    ┆ [Doc Nr. 1]                 │
# │     ┆ Armin erfasst?               ┆ spezifischen Erreger. Es    ┆  o Escherichia coli         ┆ Jedoch sind kranke und      │
# │     ┆                              ┆ hande…                      ┆  o …                        ┆ ältere Menschen…            │
# │ 106 ┆ Wann sind Zecken aktiv?      ┆ Zecke sind in Deutschland   ┆ Zecken werden bereits ab    ┆ [Doc Nr. 1]                 │
# │     ┆ Stechen Zecken auch im Win…  ┆ von März bis Oktober akt…   ┆ einer Außentemperatur von…  ┆ Erythema chronicum migrans: │
# │     ┆                              ┆                             ┆                             ┆ Wenn die s…                 │
# │ 300 ┆ Wer ist Cristiano Ronaldo?   ┆ Cristiano Ronaldo ist ein   ┆ Diese Anfrage liegt         ┆ [Doc Nr. 1]                 │
# │     ┆                              ┆ portugiesischer Fußballs…   ┆ außerhalb des               ┆ ERKRANKUNG IMPFUNG21Als     │
# │     ┆                              ┆                             ┆ gesundheitsbezog…           ┆ mögliche Neben…             │
# │ 301 ┆ Wie funktioniert ein         ┆ Die Frage nach dem          ┆ Diese Anfrage liegt         ┆ [Doc Nr. 1]                 │
# │     ┆ Elektromotor?                ┆ Funktionieren eines         ┆ außerhalb des               ┆ Je	größer	die	Temperaturdif    │
# │     ┆                              ┆ Elektromoto…                ┆ gesundheitsbezog…           ┆ ferenz	 zwi…                 │
# └─────┴──────────────────────────────┴─────────────────────────────┴─────────────────────────────┴─────────────────────────────┘

# %% [markdown]
# ### Let's define a prompt to generate responses

# %%
SYSTEM_PROMPT = """### INSTRUKTIONEN
Generiere bitte eine ANTWORT, die sich strikt an den gegebenen KONTEXT hält und präzise auf die gestellte FRAGE antwortet, ohne eigene Informationen des Modells hinzuzufügen. Falls die benötigte Information nicht im KONTEXT zu finden ist, antworte mit: 'Ihre Anfrage kann nicht mit den bereitgestellten Daten beantwortet werden. Bitte erläutern Sie Ihre Anfrage genauer oder geben Sie weitere Informationen an, falls notwendig.'. Vermeide Bezüge auf vorherige Ausgaben des Modells. Die Antwort soll auf dem bereitgestellten KONTEXT basieren. Sollte die FRAGE nicht direkt einem gesundheitsbezogenen Thema zuzuordnen sein oder nicht klar zu beantworten sein, erkläre kurz, warum die Anfrage nicht beantwortet werden kann und empfehle eine genauere Formulierung oder zusätzliche Informationen.

### KONTEXT
{context}"""

# %%
client = initialize_azure_openai_client()

def get_response(row, model):
    question = row['question'][0]
    context = row['context'][0]

    if "gpt" in model:
        response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT.format(context=context)},
            {"role": "user", "content": question},
            # {"role": "assistant", "content": "Example answer"},
            # {"role": "user", "content": "First question/message for the model to actually respond to."}
        ]
    ).choices[0].message.content
    
    return {'question': question, 'context': context, 'response': response, 'ground_truth': row['ground_truth'][0], 'model': model}

# %%
def format_response(row):
    question = row['question'][0]
    context = row['context'][0]
    response = row['response'][0]
    ground_truth = row['ground_truth'][0]
    model = CONFIG["AA_MODEL_NAME"]

    return {'question': question, 'context': context, 'response': response, 'ground_truth': ground_truth, 'model': model}

# %% [markdown]
# ### Generate responses for both the models

# %%
start_time = time.time()
results_cmodel = [get_response(dataset[idx], CONFIG["GENERATE_MODEL_NAME"]) for idx in range(len(dataset))]
results_aleph_alpha = [format_response(dataset[idx]) for idx in range(len(dataset))]

# %%
print(f"Total execution time: {time.time() - start_time:.2f} seconds")

# %%
pl.Config.set_fmt_str_lengths(50)
df = pl.DataFrame(results_cmodel)
df
# Out:
# shape: (35, 5)
# ┌─────────────────────────┬─────────────────────────┬────────────────────────┬────────────────────────┬────────────────────────┐
# │ question                ┆ context                 ┆ response               ┆ ground_truth           ┆ model                  │
# │ ---                     ┆ ---                     ┆ ---                    ┆ ---                    ┆ ---                    │
# │ str                     ┆ str                     ┆ str                    ┆ str                    ┆ str                    │
# ╞═════════════════════════╪═════════════════════════╪════════════════════════╪════════════════════════╪════════════════════════╡
# │ Wie kann ich mich vor   ┆ [Doc Nr. 1]             ┆ Um sich vor            ┆ Kaltes Wasser muss     ┆ gpt-35-turbo-16k-deplo │
# │ Legionellen schützen?   ┆ Legionellen             ┆ Legionellen zu         ┆ kalt sein, d.h. < 20   ┆ yment                  │
# │                         ┆ Vorkommen und           ┆ schützen, sollten      ┆ °C                     ┆                        │
# │                         ┆ Vermeidung              ┆ Maßna…                 ┆  Warme…                ┆                        │
# │                         ┆ T…                      ┆                        ┆                        ┆                        │
# │ Warum heißen            ┆ [Doc Nr. 1]             ┆ Der Name Legionellen   ┆ Im Juni 1976           ┆ gpt-35-turbo-16k-deplo │
# │ Legionellen so?         ┆ Jedoch sind kranke und  ┆ stammt von einem       ┆ erkrankten 221         ┆ yment                  │
# │                         ┆ ältere Menschen…        ┆ Vorfall im J…          ┆ Teilnehmer eines       ┆                        │
# │                         ┆                         ┆                        ┆ Treff…                 ┆                        │
# │ Was sind Anzeichen für  ┆ [Doc Nr. 1]             ┆ Die Anzeichen für      ┆ Wanderröte in etwa 50  ┆ gpt-35-turbo-16k-deplo │
# │ Borreliose?             ┆ Risiko Zeckenstich      ┆ Borreliose können      ┆ % der Fälle:           ┆ yment                  │
# │                         ┆ Borreliose              ┆ sein: eine min…        ┆  nach einigen …        ┆                        │
# │                         ┆ Was sind…               ┆                        ┆                        ┆                        │
# │ Sind die Lyme-Krankheit ┆ [Doc Nr. 1]             ┆ Nein, Lyme-Krankheit   ┆ Ja. (die durch         ┆ gpt-35-turbo-16k-deplo │
# │ und Borreliose das      ┆ Dieses Erkrankungsbild  ┆ und Borreliose sind    ┆ Bakterien verursachte  ┆ yment                  │
# │ selbe?                  ┆ besteht in 15 %…        ┆ nicht das…             ┆ Borreliose (L…         ┆                        │
# │ Schützt die schnelle    ┆ [Doc Nr. 1]             ┆ Nein, die schnelle     ┆ Nein/kaum. Im          ┆ gpt-35-turbo-16k-deplo │
# │ Entfernung einer Zecke  ┆ Risiko Zeckenstich      ┆ Entfernung einer Zecke ┆ Gegensatz zu der       ┆ yment                  │
# │ vor FS…                 ┆ FSME                    ┆ bietet n…              ┆ Infektion mit Borre…   ┆                        │
# │                         ┆ Schutz vor FSM…         ┆                        ┆                        ┆                        │
# │ Ist FSME tödlich?       ┆ [Doc Nr. 1]             ┆ Ja, die                ┆ Bei einem großen Teil  ┆ gpt-35-turbo-16k-deplo │
# │                         ┆ www.nlga.niedersachsen. ┆ FSME-Erkrankung kann   ┆ der Infizierten (>     ┆ yment                  │
# │                         ┆ de                      ┆ in schweren Fällen tö… ┆ 70%) und …             ┆                        │
# │                         ┆ FSME-Erkrank…           ┆                        ┆                        ┆                        │
# │ Welche Daten muss eine  ┆ [Doc Nr. 1]             ┆ Eine Bescheinigung     ┆ Die Bescheinigung muss ┆ gpt-35-turbo-16k-deplo │
# │ Bescheinigung über      ┆ (2) 1Die Person, die    ┆ über einen             ┆ Name, Vorname,         ┆ yment                  │
# │ einen du…               ┆ den Test gemäß Ab…      ┆ durchgeführten Coron…  ┆ Geburtsdatum…          ┆                        │
# │ Ich bin 80. Kann ich    ┆ [Doc Nr. 1]             ┆ Ja, als jemand im      ┆ Ja. Personen im Alter  ┆ gpt-35-turbo-16k-deplo │
# │ demnächst geimpft       ┆ 3                       ┆ Alter von 80 Jahren    ┆ von ? 80 Jahren        ┆ yment                  │
# │ werden?                 ┆                         ┆ gehören Sie …          ┆ gehören zum …          ┆                        │
# │                         ┆ 1. ALLGEMEINE FRAGEN    ┆                        ┆                        ┆                        │
# │                         ┆ ZUR IMPFUNG…            ┆                        ┆                        ┆                        │
# │ Kann ich mich auf       ┆ [Doc Nr. 1]             ┆ Ja, Sie können sich    ┆ Nein.                  ┆ gpt-35-turbo-16k-deplo │
# │ Borkum gegen Corona     ┆ 3                       ┆ auf Borkum gegen       ┆ Inselbewohnerinnen und ┆ yment                  │
# │ impfen lasse…           ┆                         ┆ Corona impfen…         ┆ -bewohner müssen sich… ┆                        │
# │                         ┆ 1. ALLGEMEINE FRAGEN    ┆                        ┆                        ┆                        │
# │                         ┆ ZUR IMPFUNG…            ┆                        ┆                        ┆                        │
# │ Wo erhalte ich weitere  ┆ [Doc Nr. 1]             ┆ Für weitere            ┆ Informationen zur      ┆ gpt-35-turbo-16k-deplo │
# │ Informationen zur       ┆ 9                       ┆ Informationen zur      ┆ Impfung können vorab   ┆ yment                  │
# │ Corona-Im…              ┆ 6. KOMMUNIKATION  UND   ┆ Corona-Impfung könne…  ┆ z.B. unter …           ┆                        │
# │                         ┆ INFORMATION …           ┆                        ┆                        ┆                        │
# │ Mein Kind ist 5. Sollte ┆ [Doc Nr. 1]             ┆ Nach den gegebenen     ┆ Nein, da nach dem      ┆ gpt-35-turbo-16k-deplo │
# │ ich es gegen            ┆ 24Impfkalender          ┆ Informationen ist      ┆ fünften Lebensjahr     ┆ yment                  │
# │ Haemophilus i…          ┆ Alter in                ┆ nicht ersicht…         ┆ Hib-Infektion…         ┆                        │
# │                         ┆ ImpfungenWoche…         ┆                        ┆                        ┆                        │
# │ Sollen Kinder gegen     ┆ [Doc Nr. 1]             ┆ Ja, Kinder sollten     ┆ Ja. Die Rotavirus-Schl ┆ gpt-35-turbo-16k-deplo │
# │ Rotaviren geimpft       ┆ ERKRANKUNG IMPFUNG18Als ┆ gegen Rotaviren        ┆ uckimpfung sollte im   ┆ yment                  │
# │ werden?                 ┆ Nebenwirkungen…         ┆ geimpft werden.…       ┆ Alter v…               ┆                        │
# │ Kann ich mich auch      ┆ [Doc Nr. 1]             ┆ Ihre Anfrage kann      ┆ Kommt drauf an.        ┆ gpt-35-turbo-16k-deplo │
# │ schwanger impfen        ┆ 3                       ┆ nicht mit den          ┆ Teilweise empfohlen    ┆ yment                  │
# │ lassen?                 ┆                         ┆ bereitgestellten D…    ┆ (Pertussis, In…        ┆                        │
# │                         ┆ 1. ALLGEMEINE FRAGEN    ┆                        ┆                        ┆                        │
# │                         ┆ ZUR IMPFUNG…            ┆                        ┆                        ┆                        │
# │ Kann ich mich nur gegen ┆ [Doc Nr. 1]             ┆ Nein, Sie können sich  ┆ Nein. Da es keinen     ┆ gpt-35-turbo-16k-deplo │
# │ Ziegenpeter impfen      ┆ ERKRANKUNG IMPFUNG19Die ┆ nicht nur gegen        ┆ Mumps-Einzelimpfstoff  ┆ yment                  │
# │ lassen?                 ┆ möglichen Nebe…         ┆ Ziegenpeter …          ┆ gibt, wir…             ┆                        │
# │ Können auch nach über   ┆ [Doc Nr. 1]             ┆ Ja, laut dem gegebenen ┆ Ja. Nebenwirkungen     ┆ gpt-35-turbo-16k-deplo │
# │ einer Woche noch        ┆ 10 Tage                 ┆ Kontext können auch    ┆ einer Impfung gegen    ┆ yment                  │
# │ Nebenwirkun…            ┆ nach der Impfung sind   ┆ nach üb…               ┆ Mumps, Mase…           ┆                        │
# │                         ┆ Sie leb…                ┆                        ┆                        ┆                        │
# │ Sollte man sich vor Sex ┆ [Doc Nr. 1]             ┆ Ihre Anfrage kann      ┆ Ja. Die HPV-Impfung    ┆ gpt-35-turbo-16k-deplo │
# │ impfen lassen?          ┆ 3                       ┆ nicht mit den          ┆ wird von der Ständigen ┆ yment                  │
# │                         ┆                         ┆ bereitgestellten D…    ┆ Impfkom…               ┆                        │
# │                         ┆ 1. ALLGEMEINE FRAGEN    ┆                        ┆                        ┆                        │
# │                         ┆ ZUR IMPFUNG…            ┆                        ┆                        ┆                        │
# │ …                       ┆ …                       ┆ …                      ┆ …                      ┆ …                      │
# │ Ich bin Rentner. Sollte ┆ [Doc Nr. 1]             ┆ Ja, wenn Sie über 60   ┆ Bei älteren Personen   ┆ gpt-35-turbo-16k-deplo │
# │ ich mich gegen          ┆ Insgesamt sind weltweit ┆ Jahre alt sind und ein ┆ scheint das Risiko für ┆ yment                  │
# │ Gelbfieber …            ┆ ca. 30 Fälle m…         ┆ hohes,…                ┆ schwer…                ┆                        │
# │ Ich habe MS. Kann ich   ┆ [Doc Nr. 1]             ┆ Ja, Sie können gegen   ┆ Bei vorliegenden       ┆ gpt-35-turbo-16k-deplo │
# │ gegen Gelbfieber        ┆ 10 Tage                 ┆ Gelbfieber geimpft     ┆ Erkrankungen des       ┆ yment                  │
# │ geimpft wer…            ┆ nach der Impfung sind   ┆ werden, so…            ┆ Nervensystems so…      ┆                        │
# │                         ┆ Sie leb…                ┆                        ┆                        ┆                        │
# │ Was muss ich nach einer ┆ [Doc Nr. 1]             ┆ Nach einer Impfung     ┆ Verhalten nach der     ┆ gpt-35-turbo-16k-deplo │
# │ Impfung gegen           ┆ 10 Tage                 ┆ gegen Gelbfieber       ┆ Impfung für die Dauer  ┆ yment                  │
# │ Gelbfieber b…           ┆ nach der Impfung sind   ┆ sollten Sie wä…        ┆ von ca. 1…             ┆                        │
# │                         ┆ Sie leb…                ┆                        ┆                        ┆                        │
# │ Woher kommt Schimmel in ┆ [Doc Nr. 1]             ┆ Schimmel in der        ┆ Ursache der            ┆ gpt-35-turbo-16k-deplo │
# │ der Wohnung?            ┆ Erythema chronicum      ┆ Wohnung entsteht       ┆ Schimmelpilzbildung in ┆ yment                  │
# │                         ┆ migrans: Wenn die s…    ┆ normalerweise dur…     ┆ Innenräumen sin…       ┆                        │
# │ Was ist SSPE?           ┆ [Doc Nr. 1]             ┆ Ihre Anfrage kann      ┆ Als sehr seltene       ┆ gpt-35-turbo-16k-deplo │
# │                         ┆ ERKRANKUNG IMPFUNG10Als ┆ nicht mit den          ┆ Komplikation einer     ┆ yment                  │
# │                         ┆ mögliche Neben…         ┆ bereitgestellten D…    ┆ Masern-Infekti…        ┆                        │
# │ Muss ich mich gegen     ┆ [Doc Nr. 1]             ┆ Eine Impfung gegen     ┆ Am 1.3.2020 ist das    ┆ gpt-35-turbo-16k-deplo │
# │ Masern impfen lassen?   ┆ ERKRANKUNG IMPFUNG16Als ┆ Masern wird generell   ┆ Masernschutzgesetz in  ┆ yment                  │
# │                         ┆ Nebenwirkungen…         ┆ empfohlen,…            ┆ Kraft ge…              ┆                        │
# │ Was ist das EKN?        ┆ [Doc Nr. 1]             ┆ Das EKN wird im        ┆ Das Land Niedersachsen ┆ gpt-35-turbo-16k-deplo │
# │                         ┆ ERKRANKUNG IMPFUNG7Als  ┆ gegebenen Kontext      ┆ hat das                ┆ yment                  │
# │                         ┆ mögliche Nebenw…        ┆ nicht erwähnt. E…      ┆ Epidemiologische Kr…   ┆                        │
# │ Kann ich mit            ┆                         ┆ Ja,                    ┆                        ┆ gpt-35-turbo-16k-deplo │
# │ Desinfektionsmitteln    ┆                         ┆ Desinfektionsmittel    ┆ Nein. Händedesinfektio ┆ yment                  │
# │ für Hände auch F…       ┆                         ┆ für Hände können auch  ┆ nsmittel dürfen nicht  ┆                        │
# │                         ┆                         ┆ zur …                  ┆ zur…                   ┆                        │
# │ Welche Erreger werden   ┆ [Doc Nr. 1]             ┆ Im gegebenen Kontext   ┆ * Gramnegative         ┆ gpt-35-turbo-16k-deplo │
# │ in Armin erfasst?       ┆ Jedoch sind kranke und  ┆ wird nicht explizit    ┆ Bakterien              ┆ yment                  │
# │                         ┆ ältere Menschen…        ┆ erwähnt, …             ┆  o Escherichia coli    ┆                        │
# │                         ┆                         ┆                        ┆  o …                   ┆                        │
# │ Wann sind Zecken aktiv? ┆ [Doc Nr. 1]             ┆ Zecken sind aktiv,     ┆ Zecken werden bereits  ┆ gpt-35-turbo-16k-deplo │
# │ Stechen Zecken auch im  ┆ Erythema chronicum      ┆ sobald die             ┆ ab einer               ┆ yment                  │
# │ Win…                    ┆ migrans: Wenn die s…    ┆ Temperaturen 8 °C er…  ┆ Außentemperatur von…   ┆                        │
# │ Wie lang ist die        ┆ [Doc Nr. 1]             ┆ Die Inkubationszeit    ┆ In der Regel dauert es ┆ gpt-35-turbo-16k-deplo │
# │ Inkubationszeit einer   ┆ ERKRANKUNG IMPFUNG16Als ┆ einer Maserninfektion  ┆ ca. 14 Tage bis nach   ┆ yment                  │
# │ Maserninfek…            ┆ Nebenwirkungen…         ┆ beträgt …              ┆ einer …                ┆                        │
# │ Gibt es eine Impfung    ┆ [Doc Nr. 1]             ┆ Nein, im gegebenen     ┆ Ja. Humane             ┆ gpt-35-turbo-16k-deplo │
# │ gegen Genitalwarzen?    ┆ Bei Infektionen         ┆ Kontext gibt es keine  ┆ Papillomviren (HPV)    ┆ yment                  │
# │                         ┆ beobachtet man zwei un… ┆ Informati…             ┆ können sowohl Haut-…   ┆                        │
# │ Was sind Nebenwirkungen ┆ [Doc Nr. 1]             ┆ Mögliche               ┆ Als mögliche           ┆ gpt-35-turbo-16k-deplo │
# │ einer Polio-Impfung?    ┆ ERKRANKUNG IMPFUNG11Als ┆ Nebenwirkungen einer   ┆ Nebenwirkungen können  ┆ yment                  │
# │                         ┆ mögliche Neben…         ┆ Polio-Impfung können…  ┆ Reaktionen an d…       ┆                        │
# │ Wie wird Borreliose     ┆ [Doc Nr. 1]             ┆ Die akute              ┆ Die akute              ┆ gpt-35-turbo-16k-deplo │
# │ behandelt?              ┆ Insbesondere            ┆ Borrelieninfektion     ┆ Borrelieninfektion     ┆ yment                  │
# │                         ┆ fortgeschrittene        ┆ kann in vielen Fällen… ┆ kann in vielen Fällen… ┆                        │
# │                         ┆ Stadien …               ┆                        ┆                        ┆                        │
# │ Wer ist Cristiano       ┆ [Doc Nr. 1]             ┆ Ihre Anfrage kann      ┆ Diese Anfrage liegt    ┆ gpt-35-turbo-16k-deplo │
# │ Ronaldo?                ┆ ERKRANKUNG IMPFUNG21Als ┆ nicht mit den          ┆ außerhalb des          ┆ yment                  │
# │                         ┆ mögliche Neben…         ┆ bereitgestellten D…    ┆ gesundheitsbezog…      ┆                        │
# │ Wie funktioniert ein    ┆ [Doc Nr. 1]             ┆ Ihre Anfrage kann      ┆ Diese Anfrage liegt    ┆ gpt-35-turbo-16k-deplo │
# │ Elektromotor?           ┆ Je	größer	die	Temperatu    ┆ nicht mit den          ┆ außerhalb des          ┆ yment                  │
# │                         ┆ rdifferenz	 zwi…         ┆ bereitgestellten D…    ┆ gesundheitsbezog…      ┆                        │
# └─────────────────────────┴─────────────────────────┴────────────────────────┴────────────────────────┴────────────────────────┘

# %% [markdown]
# ### Evaluating Experiments using UpTrain
#
# UpTrain's EvalLLM provides an `evaluate_experiments` method which takes the input data to be evaluated along with the list of checks to be run and the name of the columns associated with the experiment. The method returns a list of dictionaries containing the results of the evaluation.

# %%
from uptrain import EvalLLM, Evals, ResponseMatching, Settings

import nest_asyncio
nest_asyncio.apply()

settings = Settings(model=EVAL_MODEL_NAME, azure_api_key=CONFIG["AZURE_OPENAI_API_KEY"], azure_api_version=CONFIG["AZURE_API_VERSION"], azure_api_base=CONFIG["AZURE_API_BASE"])
eval_llm = EvalLLM(settings)

res = eval_llm.evaluate_experiments(
    project_name = f"{EXPERIMENT_NAME}-Experiments",
    data = results_cmodel + results_aleph_alpha,
    checks = [
       Evals.RESPONSE_CONCISENESS,
       ResponseMatching(method='llm'),  # Comment this if you don't have Ground Truth
       Evals.RESPONSE_COMPLETENESS_WRT_CONTEXT,
       Evals.FACTUAL_ACCURACY,
       Evals.RESPONSE_RELEVANCE,
        Evals.VALID_RESPONSE
    ],
    exp_columns=['model']
)
# Out:
# 100%|██████████| 70/70 [00:24<00:00,  2.80it/s]
#  34%|███▎      | 47/140 [00:11<00:13,  6.99it/s]2024-04-18 15:56:04.066 | ERROR    | uptrain.operators.language.llm:async_process_payload:103 - Error when sending request to LLM API: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-03-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 9 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# 2024-04-18 15:56:04.066 | INFO     | uptrain.operators.language.llm:async_process_payload:130 - Going to sleep before retrying for payload 77
# 100%|██████████| 140/140 [01:18<00:00,  1.79it/s]
# 100%|██████████| 140/140 [01:53<00:00,  1.24it/s]
# 100%|██████████| 70/70 [01:15<00:00,  1.08s/it]
# 100%|██████████| 70/70 [00:34<00:00,  2.01it/s]
# 100%|██████████| 70/70 [02:13<00:00,  1.90s/it]
# 100%|██████████| 70/70 [00:25<00:00,  2.79it/s]
# 100%|██████████| 70/70 [00:22<00:00,  3.09it/s]
# 100%|██████████| 70/70 [00:39<00:00,  1.79it/s]
# 2024-04-18 16:04:47.076 | INFO     | uptrain.framework.evalllm:evaluate:367 - Local server not running, start the server to log data and visualize in the dashboard!

# %%
print(f"Total evaluation time: {time.time() - start_time:.2f} seconds")

# %%
res_df = pl.DataFrame(res)
res_df
# Out:
# shape: (35, 35)
# ┌───────────────┬───────────────┬───────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ question      ┆ ground_truth_ ┆ ground_truth_ ┆ score_factua ┆ … ┆ score_respon ┆ score_respon ┆ explanation_ ┆ explanation_ │
# │ ---           ┆ model_gpt-35- ┆ model_luminou ┆ l_accuracy_m ┆   ┆ se_completen ┆ se_completen ┆ response_mat ┆ response_mat │
# │ str           ┆ turbo-16k-dep ┆ s-supreme-con ┆ odel_gpt-35- ┆   ┆ ess_wrt_cont ┆ ess_wrt_cont ┆ ching_model_ ┆ ching_model_ │
# │               ┆ loyment       ┆ trol          ┆ turbo-16k-de ┆   ┆ ext_model_gp ┆ ext_model_lu ┆ gpt-35-turbo ┆ luminous-sup │
# │               ┆ ---           ┆ ---           ┆ pl…          ┆   ┆ t-…          ┆ mi…          ┆ -1…          ┆ re…          │
# │               ┆ str           ┆ str           ┆ ---          ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │               ┆               ┆               ┆ f64          ┆   ┆ f64          ┆ f64          ┆ str          ┆ str          │
# ╞═══════════════╪═══════════════╪═══════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ Wie kann ich  ┆ Kaltes Wasser ┆ Kaltes Wasser ┆ 0.9          ┆ … ┆ 1.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ mich vor      ┆ muss kalt     ┆ muss kalt     ┆              ┆   ┆              ┆              ┆ Recall: 0.5{ ┆ Recall: 0.0{ │
# │ Legionellen   ┆ sein, d.h. <  ┆ sein, d.h. <  ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ schützen?     ┆ 20 °C         ┆ 20 °C         ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆  Warme…       ┆  Warme…       ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Warum heißen  ┆ Im Juni 1976  ┆ Im Juni 1976  ┆ 1.0          ┆ … ┆ 1.0          ┆ 1.0          ┆ Information  ┆ Information  │
# │ Legionellen   ┆ erkrankten    ┆ erkrankten    ┆              ┆   ┆              ┆              ┆ Recall:      ┆ Recall: 0.7{ │
# │ so?           ┆ 221           ┆ 221           ┆              ┆   ┆              ┆              ┆ 0.625{       ┆ "Result": [  │
# │               ┆ Teilnehmer    ┆ Teilnehmer    ┆              ┆   ┆              ┆              ┆ "Result": [  ┆         {…   │
# │               ┆ eines Treff…  ┆ eines Treff…  ┆              ┆   ┆              ┆              ┆        …     ┆              │
# │ Was sind      ┆ Wanderröte in ┆ Wanderröte in ┆ 1.0          ┆ … ┆ 1.0          ┆ 1.0          ┆ Information  ┆ Information  │
# │ Anzeichen für ┆ etwa 50 % der ┆ etwa 50 % der ┆              ┆   ┆              ┆              ┆ Recall: 0.2{ ┆ Recall: 0.7{ │
# │ Borreliose?   ┆ Fälle:        ┆ Fälle:        ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │               ┆ nach einigen  ┆ nach einigen  ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆ …             ┆ …             ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Sind die Lyme ┆ Ja. (die      ┆ Ja. (die      ┆ 0.75         ┆ … ┆ 0.0          ┆ 1.0          ┆ Information  ┆ Information  │
# │ -Krankheit    ┆ durch         ┆ durch         ┆              ┆   ┆              ┆              ┆ Recall:      ┆ Recall: 1.0{ │
# │ und           ┆ Bakterien     ┆ Bakterien     ┆              ┆   ┆              ┆              ┆ 0.25{        ┆ "Result": [  │
# │ Borreliose    ┆ verursachte   ┆ verursachte   ┆              ┆   ┆              ┆              ┆ "Result": [  ┆         {…   │
# │ das selbe?    ┆ Borreliose    ┆ Borreliose    ┆              ┆   ┆              ┆              ┆         …    ┆              │
# │               ┆ (L…           ┆ (L…           ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Schützt die   ┆ Nein/kaum. Im ┆ Nein/kaum. Im ┆ 1.0          ┆ … ┆ 1.0          ┆ 1.0          ┆ Information  ┆ Information  │
# │ schnelle      ┆ Gegensatz zu  ┆ Gegensatz zu  ┆              ┆   ┆              ┆              ┆ Recall: 0.5{ ┆ Recall: 0.5{ │
# │ Entfernung    ┆ der Infektion ┆ der Infektion ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ einer Zecke   ┆ mit Borre…    ┆ mit Borre…    ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ vor FS…       ┆               ┆               ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Ist FSME      ┆ Bei einem     ┆ Bei einem     ┆ 1.0          ┆ … ┆ 1.0          ┆ 0.5          ┆ Information  ┆ Information  │
# │ tödlich?      ┆ großen Teil   ┆ großen Teil   ┆              ┆   ┆              ┆              ┆ Recall: 0.5{ ┆ Recall: 0.0{ │
# │               ┆ der           ┆ der           ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │               ┆ Infizierten   ┆ Infizierten   ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆ (> 70%) und … ┆ (> 70%) und … ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Welche Daten  ┆ Die           ┆ Die           ┆ 1.0          ┆ … ┆ 1.0          ┆ 1.0          ┆ Information  ┆ Information  │
# │ muss eine     ┆ Bescheinigung ┆ Bescheinigung ┆              ┆   ┆              ┆              ┆ Recall: 1.0{ ┆ Recall: 0.8{ │
# │ Bescheinigung ┆ muss Name,    ┆ muss Name,    ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ über einen    ┆ Vorname,      ┆ Vorname,      ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ du…           ┆ Geburtsdatum… ┆ Geburtsdatum… ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Ich bin 80.   ┆ Ja. Personen  ┆ Ja. Personen  ┆ 0.8          ┆ … ┆ 1.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ Kann ich      ┆ im Alter von  ┆ im Alter von  ┆              ┆   ┆              ┆              ┆ Recall: 1.0{ ┆ Recall: 0.0{ │
# │ demnächst     ┆ ? 80 Jahren   ┆ ? 80 Jahren   ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ geimpft       ┆ gehören zum … ┆ gehören zum … ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ werden?       ┆               ┆               ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Kann ich mich ┆ Nein. Inselbe ┆ Nein. Inselbe ┆ 0.0          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ auf Borkum    ┆ wohnerinnen   ┆ wohnerinnen   ┆              ┆   ┆              ┆              ┆ Recall: 0.16 ┆ Recall: 0.0{ │
# │ gegen Corona  ┆ und -bewohner ┆ und -bewohner ┆              ┆   ┆              ┆              ┆ 666666666666 ┆ "Result": [  │
# │ impfen lasse… ┆ müssen sich…  ┆ müssen sich…  ┆              ┆   ┆              ┆              ┆ 666{         ┆         {…   │
# │               ┆               ┆               ┆              ┆   ┆              ┆              ┆     "Resu…   ┆              │
# │ Wo erhalte    ┆ Informationen ┆ Informationen ┆ 1.0          ┆ … ┆ 1.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ ich weitere   ┆ zur Impfung   ┆ zur Impfung   ┆              ┆   ┆              ┆              ┆ Recall: 0.7{ ┆ Recall: 0.0{ │
# │ Informationen ┆ können vorab  ┆ können vorab  ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ zur           ┆ z.B. unter …  ┆ z.B. unter …  ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ Corona-Im…    ┆               ┆               ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Mein Kind ist ┆ Nein, da nach ┆ Nein, da nach ┆ NaN          ┆ … ┆ 0.5          ┆ 0.0          ┆ Information  ┆ Information  │
# │ 5. Sollte ich ┆ dem fünften   ┆ dem fünften   ┆              ┆   ┆              ┆              ┆ Recall: 0.66 ┆ Recall: 0.0{ │
# │ es gegen      ┆ Lebensjahr    ┆ Lebensjahr    ┆              ┆   ┆              ┆              ┆ 666666666666 ┆ "Result": [  │
# │ Haemophilus   ┆ Hib-Infektion ┆ Hib-Infektion ┆              ┆   ┆              ┆              ┆ 66{          ┆         {…   │
# │ i…            ┆ …             ┆ …             ┆              ┆   ┆              ┆              ┆     "Resul…  ┆              │
# │ Sollen Kinder ┆ Ja. Die Rotav ┆ Ja. Die Rotav ┆ 1.0          ┆ … ┆ 1.0          ┆ 0.5          ┆ Information  ┆ Information  │
# │ gegen         ┆ irus-Schlucki ┆ irus-Schlucki ┆              ┆   ┆              ┆              ┆ Recall: 1.0{ ┆ Recall: 0.0{ │
# │ Rotaviren     ┆ mpfung sollte ┆ mpfung sollte ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ geimpft       ┆ im Alter v…   ┆ im Alter v…   ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ werden?       ┆               ┆               ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Kann ich mich ┆ Kommt drauf   ┆ Kommt drauf   ┆ NaN          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ auch          ┆ an. Teilweise ┆ an. Teilweise ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall: 0.0{ │
# │ schwanger     ┆ empfohlen     ┆ empfohlen     ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ impfen        ┆ (Pertussis,   ┆ (Pertussis,   ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ lassen?       ┆ In…           ┆ In…           ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Kann ich mich ┆ Nein. Da es   ┆ Nein. Da es   ┆ 0.0          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ nur gegen     ┆ keinen Mumps- ┆ keinen Mumps- ┆              ┆   ┆              ┆              ┆ Recall: 0.33 ┆ Recall: 0.0{ │
# │ Ziegenpeter   ┆ Einzelimpfsto ┆ Einzelimpfsto ┆              ┆   ┆              ┆              ┆ 333333333333 ┆ "Result": [  │
# │ impfen        ┆ ff gibt, wir… ┆ ff gibt, wir… ┆              ┆   ┆              ┆              ┆ 33{          ┆         {…   │
# │ lassen?       ┆               ┆               ┆              ┆   ┆              ┆              ┆     "Resul…  ┆              │
# │ Können auch   ┆ Ja. Nebenwirk ┆ Ja. Nebenwirk ┆ 1.0          ┆ … ┆ 1.0          ┆ 0.5          ┆ Information  ┆ Information  │
# │ nach über     ┆ ungen einer   ┆ ungen einer   ┆              ┆   ┆              ┆              ┆ Recall: 0.33 ┆ Recall: 0.33 │
# │ einer Woche   ┆ Impfung gegen ┆ Impfung gegen ┆              ┆   ┆              ┆              ┆ 333333333333 ┆ 333333333333 │
# │ noch          ┆ Mumps, Mase…  ┆ Mumps, Mase…  ┆              ┆   ┆              ┆              ┆ 33{          ┆ 33{          │
# │ Nebenwirkun…  ┆               ┆               ┆              ┆   ┆              ┆              ┆     "Resul…  ┆     "Resul…  │
# │ Sollte man    ┆ Ja. Die       ┆ Ja. Die       ┆ NaN          ┆ … ┆ 1.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ sich vor Sex  ┆ HPV-Impfung   ┆ HPV-Impfung   ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall: 0.0{ │
# │ impfen        ┆ wird von der  ┆ wird von der  ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ lassen?       ┆ Ständigen     ┆ Ständigen     ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆ Impfkom…      ┆ Impfkom…      ┆              ┆   ┆              ┆              ┆              ┆              │
# │ …             ┆ …             ┆ …             ┆ …            ┆ … ┆ …            ┆ …            ┆ …            ┆ …            │
# │ Ich bin       ┆ Bei älteren   ┆ Bei älteren   ┆ 0.7          ┆ … ┆ 1.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ Rentner.      ┆ Personen      ┆ Personen      ┆              ┆   ┆              ┆              ┆ Recall: 0.5{ ┆ Recall: 0.0{ │
# │ Sollte ich    ┆ scheint das   ┆ scheint das   ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ mich gegen    ┆ Risiko für    ┆ Risiko für    ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ Gelbfieber …  ┆ schwer…       ┆ schwer…       ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Ich habe MS.  ┆ Bei           ┆ Bei           ┆ 0.666667     ┆ … ┆ 0.5          ┆ 0.0          ┆ Information  ┆ Information  │
# │ Kann ich      ┆ vorliegenden  ┆ vorliegenden  ┆              ┆   ┆              ┆              ┆ Recall: 1.0{ ┆ Recall: 0.0{ │
# │ gegen         ┆ Erkrankungen  ┆ Erkrankungen  ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ Gelbfieber    ┆ des           ┆ des           ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ geimpft wer…  ┆ Nervensystems ┆ Nervensystems ┆              ┆   ┆              ┆              ┆              ┆              │
# │               ┆ so…           ┆ so…           ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Was muss ich  ┆ Verhalten     ┆ Verhalten     ┆ 1.0          ┆ … ┆ 1.0          ┆ 0.5          ┆ Information  ┆ Information  │
# │ nach einer    ┆ nach der      ┆ nach der      ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall: 0.6{ │
# │ Impfung gegen ┆ Impfung für   ┆ Impfung für   ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ Gelbfieber b… ┆ die Dauer von ┆ die Dauer von ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆ ca. 1…        ┆ ca. 1…        ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Woher kommt   ┆ Ursache der   ┆ Ursache der   ┆ 0.0          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ Schimmel in   ┆ Schimmelpilzb ┆ Schimmelpilzb ┆              ┆   ┆              ┆              ┆ Recall: 0.5{ ┆ Recall: 0.4{ │
# │ der Wohnung?  ┆ ildung in     ┆ ildung in     ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │               ┆ Innenräumen   ┆ Innenräumen   ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆ sin…          ┆ sin…          ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Was ist SSPE? ┆ Als sehr      ┆ Als sehr      ┆ NaN          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │               ┆ seltene       ┆ seltene       ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall:      │
# │               ┆ Komplikation  ┆ Komplikation  ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ 0.625{       │
# │               ┆ einer Masern- ┆ einer Masern- ┆              ┆   ┆              ┆              ┆         {…   ┆ "Result": [  │
# │               ┆ Infekti…      ┆ Infekti…      ┆              ┆   ┆              ┆              ┆              ┆        …     │
# │ Muss ich mich ┆ Am 1.3.2020   ┆ Am 1.3.2020   ┆ 1.0          ┆ … ┆ 1.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ gegen Masern  ┆ ist das Maser ┆ ist das Maser ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall: 0.0{ │
# │ impfen        ┆ nschutzgesetz ┆ nschutzgesetz ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ lassen?       ┆ in Kraft ge…  ┆ in Kraft ge…  ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ Was ist das   ┆ Das Land      ┆ Das Land      ┆ NaN          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ EKN?          ┆ Niedersachsen ┆ Niedersachsen ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall: 0.0{ │
# │               ┆ hat das Epide ┆ hat das Epide ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │               ┆ miologische   ┆ miologische   ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆ Kr…           ┆ Kr…           ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Kann ich mit  ┆               ┆               ┆ 0.0          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ Desinfektions ┆ Nein. Händede ┆ Nein. Händede ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall: 0.0{ │
# │ mitteln für   ┆ sinfektionsmi ┆ sinfektionsmi ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ Hände auch F… ┆ ttel dürfen   ┆ ttel dürfen   ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆ nicht zur…    ┆ nicht zur…    ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Welche        ┆ *             ┆ *             ┆ NaN          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ Erreger       ┆ Gramnegative  ┆ Gramnegative  ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall: 0.0{ │
# │ werden in     ┆ Bakterien     ┆ Bakterien     ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ Armin         ┆ o Escherichia ┆ o Escherichia ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ erfasst?      ┆ coli          ┆ coli          ┆              ┆   ┆              ┆              ┆              ┆              │
# │               ┆  o …          ┆  o …          ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Wann sind     ┆ Zecken werden ┆ Zecken werden ┆ 1.0          ┆ … ┆ 1.0          ┆ 0.5          ┆ Information  ┆ Information  │
# │ Zecken aktiv? ┆ bereits ab    ┆ bereits ab    ┆              ┆   ┆              ┆              ┆ Recall: 0.66 ┆ Recall: 0.33 │
# │ Stechen       ┆ einer Außente ┆ einer Außente ┆              ┆   ┆              ┆              ┆ 666666666666 ┆ 333333333333 │
# │ Zecken auch   ┆ mperatur von… ┆ mperatur von… ┆              ┆   ┆              ┆              ┆ 66{          ┆ 33{          │
# │ im Win…       ┆               ┆               ┆              ┆   ┆              ┆              ┆     "Resul…  ┆     "Resul…  │
# │ Wie lang ist  ┆ In der Regel  ┆ In der Regel  ┆ 0.0          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ die Inkubatio ┆ dauert es ca. ┆ dauert es ca. ┆              ┆   ┆              ┆              ┆ Recall: 0.5{ ┆ Recall: 0.5{ │
# │ nszeit einer  ┆ 14 Tage bis   ┆ 14 Tage bis   ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ Maserninfek…  ┆ nach einer …  ┆ nach einer …  ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ Gibt es eine  ┆ Ja. Humane    ┆ Ja. Humane    ┆ 0.0          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ Impfung gegen ┆ Papillomviren ┆ Papillomviren ┆              ┆   ┆              ┆              ┆ Recall: 0.0{ ┆ Recall: 0.0{ │
# │ Genitalwarzen ┆ (HPV) können  ┆ (HPV) können  ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │ ?             ┆ sowohl Haut-… ┆ sowohl Haut-… ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │ Was sind Nebe ┆ Als mögliche  ┆ Als mögliche  ┆ 1.0          ┆ … ┆ 1.0          ┆ 1.0          ┆ Information  ┆ Information  │
# │ nwirkungen    ┆ Nebenwirkunge ┆ Nebenwirkunge ┆              ┆   ┆              ┆              ┆ Recall: 1.0{ ┆ Recall:      │
# │ einer Polio-I ┆ n können      ┆ n können      ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ 0.75{        │
# │ mpfung?       ┆ Reaktionen an ┆ Reaktionen an ┆              ┆   ┆              ┆              ┆         {…   ┆ "Result": [  │
# │               ┆ d…            ┆ d…            ┆              ┆   ┆              ┆              ┆              ┆         …    │
# │ Wie wird      ┆ Die akute Bor ┆ Die akute Bor ┆ 1.0          ┆ … ┆ 1.0          ┆ 1.0          ┆ Information  ┆ Information  │
# │ Borreliose    ┆ relieninfekti ┆ relieninfekti ┆              ┆   ┆              ┆              ┆ Recall: 1.0{ ┆ Recall: 1.0{ │
# │ behandelt?    ┆ on kann in    ┆ on kann in    ┆              ┆   ┆              ┆              ┆ "Result": [  ┆ "Result": [  │
# │               ┆ vielen        ┆ vielen        ┆              ┆   ┆              ┆              ┆         {…   ┆         {…   │
# │               ┆ Fällen…       ┆ Fällen…       ┆              ┆   ┆              ┆              ┆              ┆              │
# │ Wer ist       ┆ Diese Anfrage ┆ Diese Anfrage ┆ NaN          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ Cristiano     ┆ liegt         ┆ liegt         ┆              ┆   ┆              ┆              ┆ Recall: nan{ ┆ Recall: nan{ │
# │ Ronaldo?      ┆ außerhalb des ┆ außerhalb des ┆              ┆   ┆              ┆              ┆ "Result": [] ┆ "Result": [] │
# │               ┆ gesundheitsbe ┆ gesundheitsbe ┆              ┆   ┆              ┆              ┆ }            ┆ }            │
# │               ┆ zog…          ┆ zog…          ┆              ┆   ┆              ┆              ┆ Inform…      ┆ Inform…      │
# │ Wie           ┆ Diese Anfrage ┆ Diese Anfrage ┆ NaN          ┆ … ┆ 0.0          ┆ 0.0          ┆ Information  ┆ Information  │
# │ funktioniert  ┆ liegt         ┆ liegt         ┆              ┆   ┆              ┆              ┆ Recall: nan{ ┆ Recall: nan{ │
# │ ein           ┆ außerhalb des ┆ außerhalb des ┆              ┆   ┆              ┆              ┆ "Result": [] ┆ "Result": [] │
# │ Elektromotor? ┆ gesundheitsbe ┆ gesundheitsbe ┆              ┆   ┆              ┆              ┆ }            ┆ }            │
# │               ┆ zog…          ┆ zog…          ┆              ┆   ┆              ┆              ┆ Inform…      ┆ Inform…      │
# └───────────────┴───────────────┴───────────────┴──────────────┴───┴──────────────┴──────────────┴──────────────┴──────────────┘

# %% [markdown]
# ### Adding Guideline Adherence evaluations

# %%
guideline = "The response must strictly adhere to the provided context and not introduce external information. If the necessary information is absent from the context, respond with: 'Ihre Anfrage kann nicht mit den bereitgestellten Daten beantwortet werden. Bitte erläutern Sie Ihre Anfrage genauer oder geben Sie weitere Informationen an, falls notwendig.'. Should the question fall outside the health-related jurisdiction of the Landesgesundheitsamt Niedersachsen, it means the query is beyond the health-related scope and shouldn't be answered."

# %%
data_cmodel_for_guideline_eval = [{'question': i['question'], 'response': i['response']} for i in results_cmodel]
data_aleph_alpha_for_guideline_eval = [{'question': i['question'], 'response': i['response']} for i in results_aleph_alpha]

# %%
from uptrain import GuidelineAdherence

def run_guideline_adherence_eval(data, guideline_name):
    return eval_llm.evaluate(
        data=data,
        checks=[GuidelineAdherence(guideline=guideline, guideline_name=guideline_name)]
    )

res_guideline_cmodel = run_guideline_adherence_eval(data_cmodel_for_guideline_eval, CONFIG["GUIDELINE_NAME"])
res_guideline_aleph_alpha = run_guideline_adherence_eval(data_aleph_alpha_for_guideline_eval, CONFIG["GUIDELINE_NAME"])
# Out:
# 100%|██████████| 35/35 [00:21<00:00,  1.65it/s]
# 2024-04-18 16:05:13.581 | INFO     | uptrain.framework.evalllm:evaluate:367 - Local server not running, start the server to log data and visualize in the dashboard!
# 100%|██████████| 35/35 [00:28<00:00,  1.21it/s]
# 2024-04-18 16:05:47.808 | INFO     | uptrain.framework.evalllm:evaluate:367 - Local server not running, start the server to log data and visualize in the dashboard!

# %%
def update_guidelines(guideline_name, res_guidelines, config_model_name):
    DEFAULT_SCORE = float("nan")
    DEFAULT_EXPLANATION = "No data available"
    score_name = 'score_' + guideline_name + '_adherence'
    explanation_name = 'explanation_' + guideline_name + '_adherence'
    
    for f in res_guidelines:
        score_key = score_name + '_model_' + config_model_name
        explanation_key = explanation_name + '_model_' + config_model_name
        
        if score_name in f:
            f[score_key] = f.pop(score_name)
        else:
            f[score_key] = DEFAULT_SCORE
        
        if explanation_name in f:
            f[explanation_key] = f.pop(explanation_name)
        else:
            if score_key not in f or f[score_key] == DEFAULT_SCORE:
                f[explanation_key] = DEFAULT_EXPLANATION

    return res_guidelines

# %%
res_guideline_cmodel = update_guidelines(CONFIG["GUIDELINE_NAME"], res_guideline_cmodel, CONFIG["GENERATE_MODEL_NAME"])
res_guideline_aleph_alpha = update_guidelines(CONFIG["GUIDELINE_NAME"], res_guideline_aleph_alpha, CONFIG["AA_MODEL_NAME"])

# %%
def merge_lists(base_list, update_list):
    update_dict = {item['question']: item for item in update_list if 'question' in item}
    
    for item in base_list:
        question = item.get('question')
        if question and question in update_dict:
            # print(f"updating with {question}")            
            update_info = {key: val for key, val in update_dict[question].items() if key != 'response'}
            item.update(update_info)
    return base_list

res=merge_lists(res, res_guideline_cmodel)
res=merge_lists(res, res_guideline_aleph_alpha)

# %% [markdown]
# ### Creating Dataframe and displaying Average Score

# %%
res_df = pl.DataFrame(res)
res_df
# Out:
# shape: (35, 39)
# ┌───────────────┬───────────────┬───────────────┬──────────────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ question      ┆ ground_truth_ ┆ ground_truth_ ┆ score_factua ┆ … ┆ score_Strict ┆ explanation_ ┆ score_Strict ┆ explanation_ │
# │ ---           ┆ model_gpt-35- ┆ model_luminou ┆ l_accuracy_m ┆   ┆ _Context_adh ┆ Strict_Conte ┆ _Context_adh ┆ Strict_Conte │
# │ str           ┆ turbo-16k-dep ┆ s-supreme-con ┆ odel_gpt-35- ┆   ┆ erence_model ┆ xt_adherence ┆ erence_model ┆ xt_adherence │
# │               ┆ loyment       ┆ trol          ┆ turbo-16k-de ┆   ┆ _gpt-35-turb ┆ _model_gpt-3 ┆ _luminous-su ┆ _model_lumin │
# │               ┆ ---           ┆ ---           ┆ pl…          ┆   ┆ o-…          ┆ 5-…          ┆ pr…          ┆ ou…          │
# │               ┆ str           ┆ str           ┆ ---          ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │               ┆               ┆               ┆ f64          ┆   ┆ f64          ┆ str          ┆ f64          ┆ str          │
# ╞═══════════════╪═══════════════╪═══════════════╪══════════════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ Wie kann ich  ┆ Kaltes Wasser ┆ Kaltes Wasser ┆ 0.9          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ mich vor      ┆ muss kalt     ┆ muss kalt     ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Legionellen   ┆ sein, d.h. <  ┆ sein, d.h. <  ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ schützen?     ┆ 20 °C         ┆ 20 °C         ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆  Warme…       ┆  Warme…       ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Warum heißen  ┆ Im Juni 1976  ┆ Im Juni 1976  ┆ 1.0          ┆ … ┆ 0.0          ┆ {            ┆ 1.0          ┆ {            │
# │ Legionellen   ┆ erkrankten    ┆ erkrankten    ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ so?           ┆ 221           ┆ 221           ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │               ┆ Teilnehmer    ┆ Teilnehmer    ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ eines Treff…  ┆ eines Treff…  ┆              ┆   ┆              ┆ provides     ┆              ┆ provides     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ informat…    ┆              ┆ informat…    │
# │ Was sind      ┆ Wanderröte in ┆ Wanderröte in ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ Anzeichen für ┆ etwa 50 % der ┆ etwa 50 % der ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Borreliose?   ┆ Fälle:        ┆ Fälle:        ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │               ┆ nach einigen  ┆ nach einigen  ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ …             ┆ …             ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Sind die Lyme ┆ Ja. (die      ┆ Ja. (die      ┆ 0.75         ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ -Krankheit    ┆ durch         ┆ durch         ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ und           ┆ Bakterien     ┆ Bakterien     ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Borreliose    ┆ verursachte   ┆ verursachte   ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ das selbe?    ┆ Borreliose    ┆ Borreliose    ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆ (L…           ┆ (L…           ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Schützt die   ┆ Nein/kaum. Im ┆ Nein/kaum. Im ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ schnelle      ┆ Gegensatz zu  ┆ Gegensatz zu  ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Entfernung    ┆ der Infektion ┆ der Infektion ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ einer Zecke   ┆ mit Borre…    ┆ mit Borre…    ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ vor FS…       ┆               ┆               ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Ist FSME      ┆ Bei einem     ┆ Bei einem     ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ tödlich?      ┆ großen Teil   ┆ großen Teil   ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │               ┆ der           ┆ der           ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │               ┆ Infizierten   ┆ Infizierten   ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ (> 70%) und … ┆ (> 70%) und … ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Welche Daten  ┆ Die           ┆ Die           ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ muss eine     ┆ Bescheinigung ┆ Bescheinigung ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Bescheinigung ┆ muss Name,    ┆ muss Name,    ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ über einen    ┆ Vorname,      ┆ Vorname,      ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ du…           ┆ Geburtsdatum… ┆ Geburtsdatum… ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Ich bin 80.   ┆ Ja. Personen  ┆ Ja. Personen  ┆ 0.8          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ Kann ich      ┆ im Alter von  ┆ im Alter von  ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ demnächst     ┆ ? 80 Jahren   ┆ ? 80 Jahren   ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ geimpft       ┆ gehören zum … ┆ gehören zum … ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ werden?       ┆               ┆               ┆              ┆   ┆              ┆ strictly     ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ the gu…      │
# │ Kann ich mich ┆ Nein. Inselbe ┆ Nein. Inselbe ┆ 0.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ auf Borkum    ┆ wohnerinnen   ┆ wohnerinnen   ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ gegen Corona  ┆ und -bewohner ┆ und -bewohner ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ impfen lasse… ┆ müssen sich…  ┆ müssen sich…  ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ strictly     ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ the gu…      │
# │ Wo erhalte    ┆ Informationen ┆ Informationen ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 0.0          ┆ {            │
# │ ich weitere   ┆ zur Impfung   ┆ zur Impfung   ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Informationen ┆ können vorab  ┆ können vorab  ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ zur           ┆ z.B. unter …  ┆ z.B. unter …  ┆              ┆   ┆              ┆ response     ┆              ┆ response is  │
# │ Corona-Im…    ┆               ┆               ┆              ┆   ┆              ┆ provides     ┆              ┆ not adhering │
# │               ┆               ┆               ┆              ┆   ┆              ┆ informat…    ┆              ┆ t…           │
# │ Mein Kind ist ┆ Nein, da nach ┆ Nein, da nach ┆ NaN          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ 5. Sollte ich ┆ dem fünften   ┆ dem fünften   ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ es gegen      ┆ Lebensjahr    ┆ Lebensjahr    ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Haemophilus   ┆ Hib-Infektion ┆ Hib-Infektion ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ i…            ┆ …             ┆ …             ┆              ┆   ┆              ┆ adheres to   ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ the gu…      ┆              ┆ the gu…      │
# │ Sollen Kinder ┆ Ja. Die Rotav ┆ Ja. Die Rotav ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ gegen         ┆ irus-Schlucki ┆ irus-Schlucki ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Rotaviren     ┆ mpfung sollte ┆ mpfung sollte ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ geimpft       ┆ im Alter v…   ┆ im Alter v…   ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ werden?       ┆               ┆               ┆              ┆   ┆              ┆ provides     ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ informat…    ┆              ┆ the gu…      │
# │ Kann ich mich ┆ Kommt drauf   ┆ Kommt drauf   ┆ NaN          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ auch          ┆ an. Teilweise ┆ an. Teilweise ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ schwanger     ┆ empfohlen     ┆ empfohlen     ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ impfen        ┆ (Pertussis,   ┆ (Pertussis,   ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ lassen?       ┆ In…           ┆ In…           ┆              ┆   ┆              ┆ strictly     ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ the gu…      │
# │ Kann ich mich ┆ Nein. Da es   ┆ Nein. Da es   ┆ 0.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ nur gegen     ┆ keinen Mumps- ┆ keinen Mumps- ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Ziegenpeter   ┆ Einzelimpfsto ┆ Einzelimpfsto ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ impfen        ┆ ff gibt, wir… ┆ ff gibt, wir… ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ lassen?       ┆               ┆               ┆              ┆   ┆              ┆ strictly     ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ the gu…      │
# │ Können auch   ┆ Ja. Nebenwirk ┆ Ja. Nebenwirk ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ nach über     ┆ ungen einer   ┆ ungen einer   ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ einer Woche   ┆ Impfung gegen ┆ Impfung gegen ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ noch          ┆ Mumps, Mase…  ┆ Mumps, Mase…  ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ Nebenwirkun…  ┆               ┆               ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Sollte man    ┆ Ja. Die       ┆ Ja. Die       ┆ NaN          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ sich vor Sex  ┆ HPV-Impfung   ┆ HPV-Impfung   ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ impfen        ┆ wird von der  ┆ wird von der  ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ lassen?       ┆ Ständigen     ┆ Ständigen     ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ Impfkom…      ┆ Impfkom…      ┆              ┆   ┆              ┆ strictly     ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ the gu…      │
# │ …             ┆ …             ┆ …             ┆ …            ┆ … ┆ …            ┆ …            ┆ …            ┆ …            │
# │ Ich bin       ┆ Bei älteren   ┆ Bei älteren   ┆ 0.7          ┆ … ┆ 1.0          ┆ {            ┆ 0.0          ┆ {            │
# │ Rentner.      ┆ Personen      ┆ Personen      ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Sollte ich    ┆ scheint das   ┆ scheint das   ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ mich gegen    ┆ Risiko für    ┆ Risiko für    ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ Gelbfieber …  ┆ schwer…       ┆ schwer…       ┆              ┆   ┆              ┆ adheres to   ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ the gu…      ┆              ┆ the gu…      │
# │ Ich habe MS.  ┆ Bei           ┆ Bei           ┆ 0.666667     ┆ … ┆ 0.0          ┆ {            ┆ 1.0          ┆ {            │
# │ Kann ich      ┆ vorliegenden  ┆ vorliegenden  ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ gegen         ┆ Erkrankungen  ┆ Erkrankungen  ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Gelbfieber    ┆ des           ┆ des           ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ geimpft wer…  ┆ Nervensystems ┆ Nervensystems ┆              ┆   ┆              ┆ provides a   ┆              ┆ adheres to   │
# │               ┆ so…           ┆ so…           ┆              ┆   ┆              ┆ detail…      ┆              ┆ the gu…      │
# │ Was muss ich  ┆ Verhalten     ┆ Verhalten     ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ nach einer    ┆ nach der      ┆ nach der      ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Impfung gegen ┆ Impfung für   ┆ Impfung für   ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Gelbfieber b… ┆ die Dauer von ┆ die Dauer von ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ ca. 1…        ┆ ca. 1…        ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Woher kommt   ┆ Ursache der   ┆ Ursache der   ┆ 0.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ Schimmel in   ┆ Schimmelpilzb ┆ Schimmelpilzb ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ der Wohnung?  ┆ ildung in     ┆ ildung in     ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │               ┆ Innenräumen   ┆ Innenräumen   ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ sin…          ┆ sin…          ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Was ist SSPE? ┆ Als sehr      ┆ Als sehr      ┆ NaN          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │               ┆ seltene       ┆ seltene       ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │               ┆ Komplikation  ┆ Komplikation  ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │               ┆ einer Masern- ┆ einer Masern- ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ Infekti…      ┆ Infekti…      ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Muss ich mich ┆ Am 1.3.2020   ┆ Am 1.3.2020   ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ gegen Masern  ┆ ist das Maser ┆ ist das Maser ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ impfen        ┆ nschutzgesetz ┆ nschutzgesetz ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ lassen?       ┆ in Kraft ge…  ┆ in Kraft ge…  ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ strictly     ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ the gu…      │
# │ Was ist das   ┆ Das Land      ┆ Das Land      ┆ NaN          ┆ … ┆ 1.0          ┆ {            ┆ 0.0          ┆ {            │
# │ EKN?          ┆ Niedersachsen ┆ Niedersachsen ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │               ┆ hat das Epide ┆ hat das Epide ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │               ┆ miologische   ┆ miologische   ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ Kr…           ┆ Kr…           ┆              ┆   ┆              ┆ strictly     ┆              ┆ introduces   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ extern…      │
# │ Kann ich mit  ┆               ┆               ┆ 0.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ Desinfektions ┆ Nein. Händede ┆ Nein. Händede ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ mitteln für   ┆ sinfektionsmi ┆ sinfektionsmi ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Hände auch F… ┆ ttel dürfen   ┆ ttel dürfen   ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ nicht zur…    ┆ nicht zur…    ┆              ┆   ┆              ┆ strictly     ┆              ┆ adheres to   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ the gu…      │
# │ Welche        ┆ *             ┆ *             ┆ NaN          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ Erreger       ┆ Gramnegative  ┆ Gramnegative  ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ werden in     ┆ Bakterien     ┆ Bakterien     ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Armin         ┆ o Escherichia ┆ o Escherichia ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ erfasst?      ┆ coli          ┆ coli          ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆  o …          ┆  o …          ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Wann sind     ┆ Zecken werden ┆ Zecken werden ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 0.0          ┆ {            │
# │ Zecken aktiv? ┆ bereits ab    ┆ bereits ab    ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Stechen       ┆ einer Außente ┆ einer Außente ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Zecken auch   ┆ mperatur von… ┆ mperatur von… ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │ im Win…       ┆               ┆               ┆              ┆   ┆              ┆ adheres to   ┆              ┆ provides     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ the pr…      ┆              ┆ informat…    │
# │ Wie lang ist  ┆ In der Regel  ┆ In der Regel  ┆ 0.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ die Inkubatio ┆ dauert es ca. ┆ dauert es ca. ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ nszeit einer  ┆ 14 Tage bis   ┆ 14 Tage bis   ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Maserninfek…  ┆ nach einer …  ┆ nach einer …  ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Gibt es eine  ┆ Ja. Humane    ┆ Ja. Humane    ┆ 0.0          ┆ … ┆ 1.0          ┆ {            ┆ 0.0          ┆ {            │
# │ Impfung gegen ┆ Papillomviren ┆ Papillomviren ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Genitalwarzen ┆ (HPV) können  ┆ (HPV) können  ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ ?             ┆ sowohl Haut-… ┆ sowohl Haut-… ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres to   ┆              ┆ introduces   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ the gu…      ┆              ┆ extern…      │
# │ Was sind Nebe ┆ Als mögliche  ┆ Als mögliche  ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ nwirkungen    ┆ Nebenwirkunge ┆ Nebenwirkunge ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ einer Polio-I ┆ n können      ┆ n können      ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ mpfung?       ┆ Reaktionen an ┆ Reaktionen an ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ d…            ┆ d…            ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Wie wird      ┆ Die akute Bor ┆ Die akute Bor ┆ 1.0          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ Borreliose    ┆ relieninfekti ┆ relieninfekti ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ behandelt?    ┆ on kann in    ┆ on kann in    ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │               ┆ vielen        ┆ vielen        ┆              ┆   ┆              ┆ response     ┆              ┆ response     │
# │               ┆ Fällen…       ┆ Fällen…       ┆              ┆   ┆              ┆ strictly     ┆              ┆ strictly     │
# │               ┆               ┆               ┆              ┆   ┆              ┆ adheres …    ┆              ┆ adheres …    │
# │ Wer ist       ┆ Diese Anfrage ┆ Diese Anfrage ┆ NaN          ┆ … ┆ 1.0          ┆ {            ┆ 0.0          ┆ {            │
# │ Cristiano     ┆ liegt         ┆ liegt         ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ Ronaldo?      ┆ außerhalb des ┆ außerhalb des ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │               ┆ gesundheitsbe ┆ gesundheitsbe ┆              ┆   ┆              ┆ question     ┆              ┆ response     │
# │               ┆ zog…          ┆ zog…          ┆              ┆   ┆              ┆ asked is     ┆              ┆ introduces   │
# │               ┆               ┆               ┆              ┆   ┆              ┆ about Cr…    ┆              ┆ extern…      │
# │ Wie           ┆ Diese Anfrage ┆ Diese Anfrage ┆ NaN          ┆ … ┆ 1.0          ┆ {            ┆ 1.0          ┆ {            │
# │ funktioniert  ┆ liegt         ┆ liegt         ┆              ┆   ┆              ┆ "Reasoning": ┆              ┆ "Reasoning": │
# │ ein           ┆ außerhalb des ┆ außerhalb des ┆              ┆   ┆              ┆ "The         ┆              ┆ "The         │
# │ Elektromotor? ┆ gesundheitsbe ┆ gesundheitsbe ┆              ┆   ┆              ┆ question     ┆              ┆ response     │
# │               ┆ zog…          ┆ zog…          ┆              ┆   ┆              ┆ asked is     ┆              ┆ correctly    │
# │               ┆               ┆               ┆              ┆   ┆              ┆ about ho…    ┆              ┆ states …     │
# └───────────────┴───────────────┴───────────────┴──────────────┴───┴──────────────┴──────────────┴──────────────┴──────────────┘

# %%
def backup_and_save_df(df, file_path, file_type='csv'):
    backup_dir = os.path.join(os.path.dirname(file_path), 'backups')
    if not os.path.exists(backup_dir):
        os.makedirs(backup_dir)
    
    if os.path.exists(file_path):
        timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
        backup_filename = os.path.basename(file_path) + f".backup-{timestamp}"
        backup_path = os.path.join(backup_dir, backup_filename)
        shutil.copy(file_path, backup_path)
    
    if file_type == 'csv':
        print(f"Saving DataFrame to CSV at: {file_path}")
        df.write_csv(file_path)
    elif file_type == 'jsonl':
        print(f"Saving DataFrame to NDJSON at: {file_path}")
        df.write_ndjson(file_path)
    
backup_and_save_df(res_df, jsonl_file_path, 'jsonl')
backup_and_save_df(res_df, csv_file_path, 'csv')
# Out:
# Saving DataFrame to NDJSON at: ./results/gpt_35_vs_luminous_supreme_experiment.jsonl
# Saving DataFrame to CSV at: ./results/gpt_35_vs_luminous_supreme_experiment.csv

# %%
def display_average_scores(df):
    score_columns = [col for col in df.columns if 'score' in col]
    data_for_table = []
    
    for column in score_columns:
        average = df[column].drop_nans().mean()
        
        parts = column.split('_model_')
        # print(f"___ parts: {parts}")
        metric_name = parts[0].replace('score_', '').replace('_', ' ').capitalize()
        model_name = parts[1]
        # print(f"metric_name: {metric_name}, average: {average}")
        # print(f"model_name: {model_name}")
        
        data_for_table.append({
            "Model": model_name,
            "Metric": metric_name,
            "Average Score": average
        })
    
    results_table = pl.DataFrame(data_for_table)
    # print(data_for_table)
    return results_table

# %%
pl.Config.set_tbl_rows(32)
pl.Config.set_fmt_str_lengths(50)
display_average_scores(res_df)
# Out:
# shape: (18, 3)
# ┌─────────────────────────────┬───────────────────────────────────┬───────────────┐
# │ Model                       ┆ Metric                            ┆ Average Score │
# │ ---                         ┆ ---                               ┆ ---           │
# │ str                         ┆ str                               ┆ f64           │
# ╞═════════════════════════════╪═══════════════════════════════════╪═══════════════╡
# │ gpt-35-turbo-16k-deployment ┆ Factual accuracy                  ┆ 0.664506      │
# │ luminous-supreme-control    ┆ Factual accuracy                  ┆ 0.482143      │
# │ gpt-35-turbo-16k-deployment ┆ Valid response                    ┆ 0.8           │
# │ luminous-supreme-control    ┆ Valid response                    ┆ 0.6           │
# │ gpt-35-turbo-16k-deployment ┆ Response conciseness              ┆ 0.914286      │
# │ luminous-supreme-control    ┆ Response conciseness              ┆ 0.842857      │
# │ gpt-35-turbo-16k-deployment ┆ Response match precision          ┆ 0.529938      │
# │ luminous-supreme-control    ┆ Response match precision          ┆ 0.347619      │
# │ gpt-35-turbo-16k-deployment ┆ Response relevance                ┆ 0.733333      │
# │ luminous-supreme-control    ┆ Response relevance                ┆ 0.538095      │
# │ gpt-35-turbo-16k-deployment ┆ Response match                    ┆ 0.359606      │
# │ luminous-supreme-control    ┆ Response match                    ┆ 0.221906      │
# │ gpt-35-turbo-16k-deployment ┆ Response match recall             ┆ 0.407323      │
# │ luminous-supreme-control    ┆ Response match recall             ┆ 0.259848      │
# │ gpt-35-turbo-16k-deployment ┆ Response completeness wrt context ┆ 0.514286      │
# │ luminous-supreme-control    ┆ Response completeness wrt context ┆ 0.3           │
# │ gpt-35-turbo-16k-deployment ┆ Strict context adherence          ┆ 0.914286      │
# │ luminous-supreme-control    ┆ Strict context adherence          ┆ 0.771429      │
# └─────────────────────────────┴───────────────────────────────────┴───────────────┘
